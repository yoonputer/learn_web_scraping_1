# %%
from selenium import webdriver

# %%
browser = webdriver.Chrome('./chromedriver.exe')
browser.get('https://github.com/login')

# %% [markdown]
# id : input#login_field
# pw : input#password
# button : input[type="submit"]

# %%
# ID
browser.find_elements_by_css_selector('input#login_field')[0].send_keys('본인 github ID')

# %% [markdown]
# ↳ list 형식이기 때문에 [0]을 넣어줌

# %%
# password
browser.find_elements_by_css_selector('input#password')[0].send_keys('본인 github PWD')

# %%
# submit
browser.find_elements_by_css_selector('input[type="submit"]')[0].click()

# %% [markdown]
# ---

# %%
browser.get('https://github.com/yoonputer/learn_web_scraping_1')

# %%
from bs4 import BeautifulSoup

# %%
html = BeautifulSoup(browser.page_source, 'html.parser')
html
# Out:
# <html data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en"><head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-55f23fa01c49298e3e64d776e2f4cf8b.css" integrity="sha512-VfI/oBxJKY4+ZNd24vTPiyumBP7aGW4fepRsD/fUTuz8Ebw8WLpgvNkCNjj8+YRFbtZUyBfJ9UTEzXippSqvaA==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/behaviors-4011b07e193ebe02a153471dd1fbb252.css" integrity="sha512-QBGwfhk+vgKhU0cd0fuyUkl8IOVe2ZRe6xHaAr2nAVqmcLmZ6jTJHONlhBDcSIC5i5rNT7CKK0Ltccp7iqE7iQ==" media="all" rel="stylesheet"/>
# ...

# %%
tags = html.select('div[role="row"].Box-row')
type(tags) , len(tags)
# Out:
# (bs4.element.ResultSet, 20)

# %%
tag = tags[0]

# %%
hre = tag.select('a[href*=""]')[0]
hre
# Out:
# <a class="js-navigation-open Link--primary" data-pjax="#repo-content-pjax-container" href="/yoonputer/learn_web_scraping_1/tree/master/files" title="files">files</a>

# %%
hre.text.strip()
# Out:
# 'selenium'

# %%
for tag in tags:
    name = tag.select('a[href*="/"] ')[0]
    desc = tag.select('a[href*="/"] ')[1]
    dates = 
    name = name.text.strip()
    desc = desc.text.strip()
    
    print(name)
    print(desc)
    print('----')
# Out:
# files
# second commit
# ----
# saves
# selenium
# ----
# .gitignore
# Initial commit
# ----
# LICENSE
# Initial commit
# ----
# README.md
# Initial commit
# ----
# beautifulsoup_htmlload.ipynb
# second commit
# ----
# bs_tags.ipynb
# second commit
# ----
# chromedriver.exe
# selenium
# ----
# genie_scraping.ipynb
# selenium
# ----
# github_login.ipynb
# selenium
# ----
# interpark_scraping.ipynb
# selenium
# ----
# melon_scraping.ipynb
# selenium
# ----
# new01.txt
# first commit
# ----
# new02.txt
# first commit
# ----
# scraping_bs4_daum_economic.ipynb
# second commit
# ----
# scraping_bs4_daum_economic_ws.ipynb
# second commit
# ----
# selenium_load.ipynb
# selenium
# ----
# starbuks_location.ipynb
# selenium
# ----
# youtube_ranking_scraping.ipynb
# selenium
# ----
# youtuberankwithpage.ipynb
# selenium
# ----

# %%
dats = tag.select('time-ago')
dats
# Out:
# [<time-ago class="no-wrap" data-view-component="true" datetime="2021-06-24T07:00:57Z" title="2021년 6월 24일 오후 4:00 GMT+9">5 days ago</time-ago>]
